# %% [markdown]
# # Housing Prices: Can you predict the home sales prices in Melbourne?

# %%
import pandas as pd
import os
from sklearn import datasets

# %%
dfHousePrices = pd.read_csv("house_prices.csv", usecols = ['Suburb', 'Rooms', 'Type', 'Price', 'Method', 'Seller', 'Date', 'Distance', 'Postcode', 'Bedroom', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude', 'Longtitude', 'Regionname', 'Propertycount']) # Remove redundant/unique information

# %%
dfHousePrices.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 1  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 2  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 3  4/03/2017       2.5    3067.0  ...       2.0  1.0      94.0           NaN
# 4  4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
dfHousePrices.describe(include='all') # This gives us a summary of the indicators
# Out:
#            Suburb         Rooms   Type         Price Method SellerG  \
# count       13580  13580.000000  13580  1.358000e+04  13580   13580
# unique        314           NaN      3           NaN      5     268
# top     Reservoir           NaN      h           NaN      S  Nelson
# freq          359           NaN   9449           NaN   9022    1565
# mean          NaN      2.937997    NaN  1.075684e+06    NaN     NaN
# std           NaN      0.955748    NaN  6.393107e+05    NaN     NaN
# min           NaN      1.000000    NaN  8.500000e+04    NaN     NaN
# 25%           NaN      2.000000    NaN  6.500000e+05    NaN     NaN
# 50%           NaN      3.000000    NaN  9.030000e+05    NaN     NaN
# 75%           NaN      3.000000    NaN  1.330000e+06    NaN     NaN
# max           NaN     10.000000    NaN  9.000000e+06    NaN     NaN
#
#               Date      Distance      Postcode      Bedroom2      Bathroom  \
# ...

# %%
print(dfHousePrices.columns.tolist())
# Out:
# ['Suburb', 'Rooms', 'Type', 'Price', 'Method', 'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Regionname', 'Propertycount']
